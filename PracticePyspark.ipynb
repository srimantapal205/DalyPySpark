# %% [markdown]
# <a href="https://colab.research.google.com/github/srimantapal205/DalyPySpark/blob/main/PracticePyspark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark

# %%
import os
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# /tmp/ipython-input-1538329743.py in <cell line: 0>()
#       1 from pyspark.sql import SparkSession
# ----> 2 spark = SparkSession.builder.getOrCreate()
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/session.py in getOrCreate(self)
#     495                         sparkConf.set(key, value)
#     496                     # This SparkContext may be an existing one.
# --> 497                     sc = SparkContext.getOrCreate(sparkConf)
#     498                     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     499                     # by all sessions.
#
# /usr/local/lib/python3.12/dist-packages/pyspark/context.py in getOrCreate(cls, conf)
#     513         with SparkContext._lock:
#     514             if SparkContext._active_spark_context is None:
# ...

# %%
data = {
    "order_id": 1001,
    "customer": {"id": 50, "name": "Riya"},
    "items": [
        {"sku": "A1", "qty": 2, "price": 100},
        {"sku": "B1", "qty": 1, "price": 200}
    ]
}


df = spark.read.json(spark.sparkContext.parallelize([data]))
df.show(truncate=False)
